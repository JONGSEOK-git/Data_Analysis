# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('exam.csv', index_col = 0)
df
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# ...

# %%
df.plot(kind='scatter', x='math score', y='reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
df.plot(kind='scatter', x='math score', y='writing score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
df.plot(kind='scatter', x='reading score', y='writing score')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
data=pd.read_csv('world_indexes.csv', index_col=0)
data
# Out:
#                           Human Development Index HDI-2014  \
# Id
# Norway                                            0.943877
# Australia                                         0.934958
# Switzerland                                       0.929613
# Denmark                                           0.923328
# Netherlands                                       0.921794
# ...                                                    ...
# Burundi                                           0.399928
# Chad                                              0.391906
# Eritrea                                           0.390899
# Central African Republic                          0.350131
# Niger                                             0.348254
#
#                           Gini coefficient 2005-2013  \
# Id
# Norway                                         26.83
# Australia                                      34.01
# Switzerland                                    32.35
# ...

# %%
data.plot(kind='scatter', x='Life expectancy at birth- years', y='Internet users percentage of population 2014')
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth- years', ylabel='Internet users percentage of population 2014'>

# %%
data.plot(kind='scatter', x='Life expectancy at birth- years', y='Carbon dioxide emissionsAverage annual growth')
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth- years', ylabel='Carbon dioxide emissionsAverage annual growth'>

# %%
data.plot(kind='scatter', x='Life expectancy at birth- years', y='Forest area percentage of total land area 2012')
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth- years', ylabel='Forest area percentage of total land area 2012'>

# %%
data.plot(kind='scatter', x='Carbon dioxide emissionsAverage annual growth', y='Forest area percentage of total land area 2012')
# Out:
# <AxesSubplot:xlabel='Carbon dioxide emissionsAverage annual growth', ylabel='Forest area percentage of total land area 2012'>

# %%
data.plot(kind='scatter', x='Internet users percentage of population 2014', y='Forest area percentage of total land area 2012')
# Out:
# <AxesSubplot:xlabel='Internet users percentage of population 2014', ylabel='Forest area percentage of total land area 2012'>
